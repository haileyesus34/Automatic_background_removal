# %% [markdown]
# <a href="https://www.kaggle.com/code/haileyesusmengistu/soccer-pitch-detection?scriptVersionId=210679898" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.9/896.9 kB 18.5 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="7GunUkGvcBHgWVjcJJoS")
project = rf.workspace("haile").project("pitch-detection-j2hsc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 2.9 MB/s eta 0:00:00
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to pitch-detection-1 in yolov8:: 100%|██████████| 1986/1986 [00:00<00:00, 2654.08it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
ls
# Out:
# __notebook__.ipynb  pitch-detection-1/

# %%
import shutil

# %%
import yaml

# Path to your YAML file
yaml_file_path = '/kaggle/working/pitch-detection-1/data.yaml'

# Read the YAML file
with open(yaml_file_path, 'r') as file:
    data = yaml.safe_load(file)
    print(data)  # View the current contents
# Out:
# {'flip_idx': [24, 25, 26, 27, 28, 29, 22, 23, 21, 17, 18, 19, 20, 13, 14, 15, 16, 9, 10, 11, 12, 8, 6, 7, 0, 1, 2, 3, 4, 5, 31, 30], 'kpt_shape': [32, 3], 'names': ['pitch'], 'nc': 1, 'roboflow': {'license': 'CC BY 4.0', 'project': 'pitch-detection-j2hsc', 'url': 'https://universe.roboflow.com/haile/pitch-detection-j2hsc/dataset/1', 'version': 1, 'workspace': 'haile'}, 'test': '../test/images', 'train': '../train/images', 'val': '../valid/images'}

# %%
data['test'] = '/kaggle/working/pitch-detection-1/pitch-detection-1/test/images'  # Add or modify entries
data['train'] = '/kaggle/working/pitch-detection-1/pitch-detection-1/train/images'
data['val'] = '/kaggle/working/pitch-detection-1/pitch-detection-1/valid/images'

print(data)  # Check the modified content
# Out:
# {'flip_idx': [24, 25, 26, 27, 28, 29, 22, 23, 21, 17, 18, 19, 20, 13, 14, 15, 16, 9, 10, 11, 12, 8, 6, 7, 0, 1, 2, 3, 4, 5, 31, 30], 'kpt_shape': [32, 3], 'names': ['pitch'], 'nc': 1, 'roboflow': {'license': 'CC BY 4.0', 'project': 'pitch-detection-j2hsc', 'url': 'https://universe.roboflow.com/haile/pitch-detection-j2hsc/dataset/1', 'version': 1, 'workspace': 'haile'}, 'test': '/kaggle/working/pitch-detection-1/pitch-detection-1/test/images', 'train': '/kaggle/working/pitch-detection-1/pitch-detection-1/train/images', 'val': '/kaggle/working/pitch-detection-1/pitch-detection-1/valid/images'}

# %%
with open(yaml_file_path, 'w') as file:
    yaml.dump(data, file)

# %%
dataset.location
# Out:
# '/kaggle/working/pitch-detection-1'

# %%
# !yolo task=pose mode=train model='/kaggle/input/kpt/other/default/1/kpt_detection_last1.pt' data={dataset.location}/data.yaml epochs=50 imgsz=640 batch=1
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.14 torch-2.4.0+cpu CPU (Intel Xeon 2.20GHz)
# ...
